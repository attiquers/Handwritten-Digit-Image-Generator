# %%
# conditional_gan_training.ipynb

import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Hyperparameters
z_dim = 100 # Dimension of the noise vector
num_classes = 10 # For MNIST digits 0-9
image_dim = 28 * 28 # 784 for MNIST (28x28 grayscale)
batch_size = 64
num_epochs = 50 # Adjust as needed. Start with 50-100, observe results.
lr = 0.0002
b1 = 0.5 # Adam: decay of first order momentum of gradients
b2 = 0.999 # Adam: decay of second order momentum of gradients

# MNIST Dataset loading and transformation
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,)) # Normalize to [-1, 1]
])

mnist_dataset = datasets.MNIST(root='./data', train=True, transform=transform, download=True)
dataloader = DataLoader(mnist_dataset, batch_size=batch_size, shuffle=True)

# Conditional Generator Definition
class ConditionalGenerator(nn.Module):
    def __init__(self, z_dim, num_classes, img_dim):
        super().__init__()
        # Embedding layer to convert class labels (0-9) into a dense vector
        self.label_emb = nn.Embedding(num_classes, num_classes)
        self.main = nn.Sequential(
            nn.Linear(z_dim + num_classes, 256), # Concatenate noise and label embedding
            nn.LeakyReLU(0.2),
            nn.Linear(256, 512),
            nn.LeakyReLU(0.2),
            nn.Linear(512, 1024),
            nn.LeakyReLU(0.2),
            nn.Linear(1024, img_dim),
            nn.Tanh() # Output in range [-1, 1]
        )

    def forward(self, noise, labels):
        # Ensure labels are of type torch.long for nn.Embedding
        c = self.label_emb(labels.long())
        input_tensor = torch.cat([noise, c], 1) # Concatenate along dimension 1 (columns)
        return self.main(input_tensor).view(-1, 1, 28, 28) # Reshape to 1 channel, 28x28 image

# Conditional Discriminator Definition
class ConditionalDiscriminator(nn.Module):
    def __init__(self, num_classes, img_dim):
        super().__init__()
        # Embedding layer for class labels
        self.label_emb = nn.Embedding(num_classes, num_classes)
        self.main = nn.Sequential(
            nn.Linear(img_dim + num_classes, 1024), # Concatenate flattened image and label embedding
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3), # Dropout for regularization
            nn.Linear(1024, 512),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),
            nn.Linear(256, 1),
            nn.Sigmoid() # Output a probability between 0 and 1
        )

    def forward(self, img, labels):
        img_flat = img.view(img.size(0), -1) # Flatten the image
        # Ensure labels are of type torch.long for nn.Embedding
        c = self.label_emb(labels.long())
        input_tensor = torch.cat([img_flat, c], 1)
        return self.main(input_tensor)

# Initialize Conditional Generator and Discriminator
generator = ConditionalGenerator(z_dim, num_classes, image_dim).to(device)
discriminator = ConditionalDiscriminator(num_classes, image_dim).to(device)

# Loss function and optimizers
criterion = nn.BCELoss() # Binary Cross Entropy Loss for GANs
optimizer_D = optim.Adam(discriminator.parameters(), lr=lr, betas=(b1, b2))
optimizer_G = optim.Adam(generator.parameters(), lr=lr, betas=(b1, b2))

# Training Loop for CGAN
print("Starting Conditional GAN Training Loop...")
for epoch in range(num_epochs):
    for i, (imgs, labels) in enumerate(dataloader):
        # Configure input
        real_imgs = imgs.to(device)
        real_labels_tensor = labels.to(device) # Labels corresponding to real images

        # Adversarial ground truths (for discriminator and generator loss)
        real_gan_labels = torch.ones(real_imgs.size(0), 1).to(device)
        fake_gan_labels = torch.zeros(real_imgs.size(0), 1).to(device)

        # ---------------------
        #  Train Discriminator
        # ---------------------
        optimizer_D.zero_grad()

        # Measure discriminator's ability to classify real images
        output_real = discriminator(real_imgs, real_labels_tensor)
        d_loss_real = criterion(output_real, real_gan_labels)

        # Measure discriminator's ability to classify fake images
        z = torch.randn(real_imgs.size(0), z_dim).to(device) # Noise vector
        # Generate random labels for fake images for the discriminator's fake input
        # This helps the discriminator learn to differentiate all types of fake digits
        fake_labels_tensor_D = torch.randint(0, num_classes, (real_imgs.size(0),)).to(device)
        fake_imgs = generator(z, fake_labels_tensor_D)

        # Detach fake_imgs and fake_labels_tensor_D to prevent gradients from flowing to Generator
        output_fake = discriminator(fake_imgs.detach(), fake_labels_tensor_D.detach())
        d_loss_fake = criterion(output_fake, fake_gan_labels)

        # Total discriminator loss (average of real and fake loss)
        d_loss = (d_loss_real + d_loss_fake) / 2
        d_loss.backward()
        optimizer_D.step()

        # -----------------
        #  Train Generator
        # -----------------
        optimizer_G.zero_grad()

        # Generate fake images
        z = torch.randn(real_imgs.size(0), z_dim).to(device)
        # Generate random labels for the generator's target. The generator tries to make fake images
        # that the discriminator will classify as 'real' with these labels.
        gen_target_labels = torch.randint(0, num_classes, (real_imgs.size(0),)).to(device)
        fake_imgs = generator(z, gen_target_labels)

        # Loss measures generator's ability to fool the discriminator
        # The generator wants the discriminator to output '1' (real) for its fake images
        output = discriminator(fake_imgs, gen_target_labels)
        g_loss = criterion(output, real_gan_labels)

        g_loss.backward()
        optimizer_G.step()

        if (i + 1) % 100 == 0:
            print(
                f"Epoch [{epoch+1}/{num_epochs}], Batch [{i+1}/{len(dataloader)}] "
                f"D Loss: {d_loss.item():.4f}, G Loss: {g_loss.item():.4f}"
            )

    # Save generated images for visual inspection (conditional on a specific digit)
    # This block generates 5 images of a chosen digit (e.g., '7') to see training progress.
    if (epoch + 1) % 10 == 0 or epoch == num_epochs - 1: # Also save on the last epoch
        with torch.no_grad():
            test_digit = 7 # Example: generate images of digit 7
            fixed_noise = torch.randn(5, z_dim).to(device)
            # Create labels for the specific digit we want to generate
            fixed_labels = torch.full((5,), test_digit, dtype=torch.long).to(device)
            generated_images = generator(fixed_noise, fixed_labels).cpu().detach()

            # Denormalize images from [-1, 1] to [0, 1] for plotting
            generated_images = (generated_images + 1) / 2

            fig, axes = plt.subplots(1, 5, figsize=(10, 2))
            for img_idx, img in enumerate(generated_images):
                axes[img_idx].imshow(img.squeeze(), cmap='gray')
                axes[img_idx].axis('off')
            plt.suptitle(f'Generated Digit {test_digit} at Epoch {epoch+1}')
            plt.show()

# Save the trained generator model's state dictionary
# This is the file you'll need for your web app
torch.save(generator.state_dict(), 'conditional_generator_mnist.pth')
print("Training complete. Conditional Generator model saved as conditional_generator_mnist.pth")
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 18.1MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 494kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 3.93MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 6.98MB/s]
# Starting Conditional GAN Training Loop...
# Epoch [1/50], Batch [100/938] D Loss: 0.5338, G Loss: 1.1045
# Epoch [1/50], Batch [200/938] D Loss: 0.5356, G Loss: 1.1640
# Epoch [1/50], Batch [300/938] D Loss: 0.2171, G Loss: 2.8902
# Epoch [1/50], Batch [400/938] D Loss: 0.2352, G Loss: 3.6426
# Epoch [1/50], Batch [500/938] D Loss: 0.5250, G Loss: 4.7029
# Epoch [1/50], Batch [600/938] D Loss: 0.4914, G Loss: 7.6508
# Epoch [1/50], Batch [700/938] D Loss: 0.3827, G Loss: 2.8862
# Epoch [1/50], Batch [800/938] D Loss: 0.1444, G Loss: 3.9371
# Epoch [1/50], Batch [900/938] D Loss: 0.3994, G Loss: 3.3834
# Epoch [2/50], Batch [100/938] D Loss: 0.1933, G Loss: 5.4973
# Epoch [2/50], Batch [200/938] D Loss: 0.4628, G Loss: 3.5532
# Epoch [2/50], Batch [300/938] D Loss: 0.2347, G Loss: 2.6129
# Epoch [2/50], Batch [400/938] D Loss: 0.2532, G Loss: 2.7117
# Epoch [2/50], Batch [500/938] D Loss: 0.2481, G Loss: 1.6295
# Epoch [2/50], Batch [600/938] D Loss: 0.1785, G Loss: 3.9676
# Epoch [2/50], Batch [700/938] D Loss: 0.1205, G Loss: 3.1368
# Epoch [2/50], Batch [800/938] D Loss: 0.2413, G Loss: 3.6068
# Epoch [2/50], Batch [900/938] D Loss: 0.2125, G Loss: 2.7807
# Epoch [3/50], Batch [100/938] D Loss: 0.3121, G Loss: 2.1975
# Epoch [3/50], Batch [200/938] D Loss: 0.2396, G Loss: 2.2308
# Epoch [3/50], Batch [300/938] D Loss: 0.4390, G Loss: 2.6185
# Epoch [3/50], Batch [400/938] D Loss: 0.3346, G Loss: 2.1781
# Epoch [3/50], Batch [500/938] D Loss: 0.2745, G Loss: 3.2669
# Epoch [3/50], Batch [600/938] D Loss: 0.2764, G Loss: 2.3244
# Epoch [3/50], Batch [700/938] D Loss: 0.3526, G Loss: 3.1603
# Epoch [3/50], Batch [800/938] D Loss: 0.2959, G Loss: 2.2841
# Epoch [3/50], Batch [900/938] D Loss: 0.3688, G Loss: 1.5316
# Epoch [4/50], Batch [100/938] D Loss: 0.2446, G Loss: 1.9766
# Epoch [4/50], Batch [200/938] D Loss: 0.2892, G Loss: 1.9468
# Epoch [4/50], Batch [300/938] D Loss: 0.3026, G Loss: 1.4851
# Epoch [4/50], Batch [400/938] D Loss: 0.2764, G Loss: 3.0500
# Epoch [4/50], Batch [500/938] D Loss: 0.3376, G Loss: 1.8145
# Epoch [4/50], Batch [600/938] D Loss: 0.3523, G Loss: 3.2329
# Epoch [4/50], Batch [700/938] D Loss: 0.4344, G Loss: 1.2121
# Epoch [4/50], Batch [800/938] D Loss: 0.3906, G Loss: 2.0296
# Epoch [4/50], Batch [900/938] D Loss: 0.3316, G Loss: 1.8411
# Epoch [5/50], Batch [100/938] D Loss: 0.3139, G Loss: 2.2211
# Epoch [5/50], Batch [200/938] D Loss: 0.4235, G Loss: 1.9960
# Epoch [5/50], Batch [300/938] D Loss: 0.4112, G Loss: 1.1714
# Epoch [5/50], Batch [400/938] D Loss: 0.3707, G Loss: 3.0679
# Epoch [5/50], Batch [500/938] D Loss: 0.3973, G Loss: 1.5306
# Epoch [5/50], Batch [600/938] D Loss: 0.3596, G Loss: 1.2237
# Epoch [5/50], Batch [700/938] D Loss: 0.4691, G Loss: 1.1973
# Epoch [5/50], Batch [800/938] D Loss: 0.5559, G Loss: 1.8142
# Epoch [5/50], Batch [900/938] D Loss: 0.4080, G Loss: 1.3852
# Epoch [6/50], Batch [100/938] D Loss: 0.3558, G Loss: 1.6839
# Epoch [6/50], Batch [200/938] D Loss: 0.3716, G Loss: 1.9180
# Epoch [6/50], Batch [300/938] D Loss: 0.4048, G Loss: 1.3870
# Epoch [6/50], Batch [400/938] D Loss: 0.4649, G Loss: 1.0669
# Epoch [6/50], Batch [500/938] D Loss: 0.4373, G Loss: 1.4598
# Epoch [6/50], Batch [600/938] D Loss: 0.4161, G Loss: 1.7012
# Epoch [6/50], Batch [700/938] D Loss: 0.5103, G Loss: 1.6441
# Epoch [6/50], Batch [800/938] D Loss: 0.4292, G Loss: 1.7264
# Epoch [6/50], Batch [900/938] D Loss: 0.4241, G Loss: 1.0356
# Epoch [7/50], Batch [100/938] D Loss: 0.5281, G Loss: 1.7284
# Epoch [7/50], Batch [200/938] D Loss: 0.5500, G Loss: 1.4400
# Epoch [7/50], Batch [300/938] D Loss: 0.4779, G Loss: 1.7868
# Epoch [7/50], Batch [400/938] D Loss: 0.4773, G Loss: 1.3851
# Epoch [7/50], Batch [500/938] D Loss: 0.5671, G Loss: 0.8968
# Epoch [7/50], Batch [600/938] D Loss: 0.4518, G Loss: 1.2203
# Epoch [7/50], Batch [700/938] D Loss: 0.5033, G Loss: 1.2598
# Epoch [7/50], Batch [800/938] D Loss: 0.4857, G Loss: 1.4028
# Epoch [7/50], Batch [900/938] D Loss: 0.5114, G Loss: 1.1967
# Epoch [8/50], Batch [100/938] D Loss: 0.5306, G Loss: 1.4100
# Epoch [8/50], Batch [200/938] D Loss: 0.5009, G Loss: 1.1721
# Epoch [8/50], Batch [300/938] D Loss: 0.5276, G Loss: 1.2732
# Epoch [8/50], Batch [400/938] D Loss: 0.6043, G Loss: 1.0563
# Epoch [8/50], Batch [500/938] D Loss: 0.7008, G Loss: 1.8671
# Epoch [8/50], Batch [600/938] D Loss: 0.5493, G Loss: 1.2079
# Epoch [8/50], Batch [700/938] D Loss: 0.5435, G Loss: 1.3647
# Epoch [8/50], Batch [800/938] D Loss: 0.5601, G Loss: 1.3290
# Epoch [8/50], Batch [900/938] D Loss: 0.5919, G Loss: 1.0889
# Epoch [9/50], Batch [100/938] D Loss: 0.6011, G Loss: 1.1769
# Epoch [9/50], Batch [200/938] D Loss: 0.5714, G Loss: 1.1407
# Epoch [9/50], Batch [300/938] D Loss: 0.5244, G Loss: 1.1563
# Epoch [9/50], Batch [400/938] D Loss: 0.6637, G Loss: 0.8916
# Epoch [9/50], Batch [500/938] D Loss: 0.5314, G Loss: 0.9055
# Epoch [9/50], Batch [600/938] D Loss: 0.6133, G Loss: 1.4182
# Epoch [9/50], Batch [700/938] D Loss: 0.5597, G Loss: 1.3143
# Epoch [9/50], Batch [800/938] D Loss: 0.5312, G Loss: 1.2247
# Epoch [9/50], Batch [900/938] D Loss: 0.6291, G Loss: 1.0633
# Epoch [10/50], Batch [100/938] D Loss: 0.6554, G Loss: 1.2888
# Epoch [10/50], Batch [200/938] D Loss: 0.5756, G Loss: 0.9305
# Epoch [10/50], Batch [300/938] D Loss: 0.5933, G Loss: 0.7845
# Epoch [10/50], Batch [400/938] D Loss: 0.5989, G Loss: 1.0369
# Epoch [10/50], Batch [500/938] D Loss: 0.5839, G Loss: 0.6448
# Epoch [10/50], Batch [600/938] D Loss: 0.6316, G Loss: 1.2521
# Epoch [10/50], Batch [700/938] D Loss: 0.6115, G Loss: 0.9828
# Epoch [10/50], Batch [800/938] D Loss: 0.5830, G Loss: 0.9512
# Epoch [10/50], Batch [900/938] D Loss: 0.6180, G Loss: 1.2330
# Epoch [11/50], Batch [100/938] D Loss: 0.6030, G Loss: 0.9911
# Epoch [11/50], Batch [200/938] D Loss: 0.5972, G Loss: 1.2546
# Epoch [11/50], Batch [300/938] D Loss: 0.6466, G Loss: 1.0918
# Epoch [11/50], Batch [400/938] D Loss: 0.5610, G Loss: 1.0838
# Epoch [11/50], Batch [500/938] D Loss: 0.5685, G Loss: 1.0616
# Epoch [11/50], Batch [600/938] D Loss: 0.7288, G Loss: 0.7930
# Epoch [11/50], Batch [700/938] D Loss: 0.5795, G Loss: 0.9561
# Epoch [11/50], Batch [800/938] D Loss: 0.6315, G Loss: 1.0972
# Epoch [11/50], Batch [900/938] D Loss: 0.5873, G Loss: 0.9431
# Epoch [12/50], Batch [100/938] D Loss: 0.5633, G Loss: 0.9595
# Epoch [12/50], Batch [200/938] D Loss: 0.6499, G Loss: 0.8553
# Epoch [12/50], Batch [300/938] D Loss: 0.6085, G Loss: 1.0726
# Epoch [12/50], Batch [400/938] D Loss: 0.6318, G Loss: 1.0493
# Epoch [12/50], Batch [500/938] D Loss: 0.5938, G Loss: 0.8721
# Epoch [12/50], Batch [600/938] D Loss: 0.6065, G Loss: 0.7970
# Epoch [12/50], Batch [700/938] D Loss: 0.5914, G Loss: 0.9210
# Epoch [12/50], Batch [800/938] D Loss: 0.5935, G Loss: 1.0787
# Epoch [12/50], Batch [900/938] D Loss: 0.5732, G Loss: 0.9347
# Epoch [13/50], Batch [100/938] D Loss: 0.5807, G Loss: 1.1409
# Epoch [13/50], Batch [200/938] D Loss: 0.5836, G Loss: 1.1592
# Epoch [13/50], Batch [300/938] D Loss: 0.6712, G Loss: 1.0303
# Epoch [13/50], Batch [400/938] D Loss: 0.5999, G Loss: 0.7549
# Epoch [13/50], Batch [500/938] D Loss: 0.6479, G Loss: 1.0654
# Epoch [13/50], Batch [600/938] D Loss: 0.5898, G Loss: 1.0208
# Epoch [13/50], Batch [700/938] D Loss: 0.5996, G Loss: 0.7930
# Epoch [13/50], Batch [800/938] D Loss: 0.6308, G Loss: 0.8912
# Epoch [13/50], Batch [900/938] D Loss: 0.6030, G Loss: 0.8869
# Epoch [14/50], Batch [100/938] D Loss: 0.6475, G Loss: 0.9212
# Epoch [14/50], Batch [200/938] D Loss: 0.5732, G Loss: 0.8256
# Epoch [14/50], Batch [300/938] D Loss: 0.6622, G Loss: 0.8015
# Epoch [14/50], Batch [400/938] D Loss: 0.6861, G Loss: 1.1478
# Epoch [14/50], Batch [500/938] D Loss: 0.6299, G Loss: 0.9288
# Epoch [14/50], Batch [600/938] D Loss: 0.6613, G Loss: 0.9163
# Epoch [14/50], Batch [700/938] D Loss: 0.6796, G Loss: 0.8989
# Epoch [14/50], Batch [800/938] D Loss: 0.6807, G Loss: 0.8441
# Epoch [14/50], Batch [900/938] D Loss: 0.6146, G Loss: 0.7691
# Epoch [15/50], Batch [100/938] D Loss: 0.6380, G Loss: 1.1004
# Epoch [15/50], Batch [200/938] D Loss: 0.6436, G Loss: 0.8470
# Epoch [15/50], Batch [300/938] D Loss: 0.6047, G Loss: 0.9546
# Epoch [15/50], Batch [400/938] D Loss: 0.6305, G Loss: 0.8881
# Epoch [15/50], Batch [500/938] D Loss: 0.5963, G Loss: 0.9169
# Epoch [15/50], Batch [600/938] D Loss: 0.6506, G Loss: 0.8838
# Epoch [15/50], Batch [700/938] D Loss: 0.5991, G Loss: 0.8736
# Epoch [15/50], Batch [800/938] D Loss: 0.6351, G Loss: 0.9839
# Epoch [15/50], Batch [900/938] D Loss: 0.6475, G Loss: 0.8296
# Epoch [16/50], Batch [100/938] D Loss: 0.6435, G Loss: 0.9809
# Epoch [16/50], Batch [200/938] D Loss: 0.6618, G Loss: 0.9516
# Epoch [16/50], Batch [300/938] D Loss: 0.6805, G Loss: 0.9657
# Epoch [16/50], Batch [400/938] D Loss: 0.6537, G Loss: 0.9189
# Epoch [16/50], Batch [500/938] D Loss: 0.5949, G Loss: 0.9346
# Epoch [16/50], Batch [600/938] D Loss: 0.6035, G Loss: 0.9824
# Epoch [16/50], Batch [700/938] D Loss: 0.6454, G Loss: 0.9887
# Epoch [16/50], Batch [800/938] D Loss: 0.7151, G Loss: 0.6918
# Epoch [16/50], Batch [900/938] D Loss: 0.7036, G Loss: 0.8115
# Epoch [17/50], Batch [100/938] D Loss: 0.6358, G Loss: 0.9394
# Epoch [17/50], Batch [200/938] D Loss: 0.6384, G Loss: 1.0528
# Epoch [17/50], Batch [300/938] D Loss: 0.6415, G Loss: 0.7825
# Epoch [17/50], Batch [400/938] D Loss: 0.6635, G Loss: 0.8705
# Epoch [17/50], Batch [500/938] D Loss: 0.6191, G Loss: 0.9043
# Epoch [17/50], Batch [600/938] D Loss: 0.6397, G Loss: 0.8036
# Epoch [17/50], Batch [700/938] D Loss: 0.6636, G Loss: 0.9054
# Epoch [17/50], Batch [800/938] D Loss: 0.6190, G Loss: 0.9661
# Epoch [17/50], Batch [900/938] D Loss: 0.6650, G Loss: 1.0329
# Epoch [18/50], Batch [100/938] D Loss: 0.6541, G Loss: 0.6486
# Epoch [18/50], Batch [200/938] D Loss: 0.6395, G Loss: 0.9020
# Epoch [18/50], Batch [300/938] D Loss: 0.6262, G Loss: 0.7996
# Epoch [18/50], Batch [400/938] D Loss: 0.6713, G Loss: 0.9649
# Epoch [18/50], Batch [500/938] D Loss: 0.5843, G Loss: 0.8384
# Epoch [18/50], Batch [600/938] D Loss: 0.6323, G Loss: 0.8501
# Epoch [18/50], Batch [700/938] D Loss: 0.6343, G Loss: 0.8320
# Epoch [18/50], Batch [800/938] D Loss: 0.6758, G Loss: 0.8217
# Epoch [18/50], Batch [900/938] D Loss: 0.7312, G Loss: 0.8848
# Epoch [19/50], Batch [100/938] D Loss: 0.6400, G Loss: 1.0309
# Epoch [19/50], Batch [200/938] D Loss: 0.6394, G Loss: 0.8755
# Epoch [19/50], Batch [300/938] D Loss: 0.6345, G Loss: 0.9339
# Epoch [19/50], Batch [400/938] D Loss: 0.6426, G Loss: 0.9040
# Epoch [19/50], Batch [500/938] D Loss: 0.6448, G Loss: 0.9254
# Epoch [19/50], Batch [600/938] D Loss: 0.7118, G Loss: 0.9315
# Epoch [19/50], Batch [700/938] D Loss: 0.6488, G Loss: 0.7520
# Epoch [19/50], Batch [800/938] D Loss: 0.6216, G Loss: 0.7545
# Epoch [19/50], Batch [900/938] D Loss: 0.6104, G Loss: 0.8381
# Epoch [20/50], Batch [100/938] D Loss: 0.6721, G Loss: 0.7719
# Epoch [20/50], Batch [200/938] D Loss: 0.6479, G Loss: 0.8923
# Epoch [20/50], Batch [300/938] D Loss: 0.6178, G Loss: 0.9538
# Epoch [20/50], Batch [400/938] D Loss: 0.6240, G Loss: 0.8108
# Epoch [20/50], Batch [500/938] D Loss: 0.5969, G Loss: 0.8770
# Epoch [20/50], Batch [600/938] D Loss: 0.6287, G Loss: 0.8740
# Epoch [20/50], Batch [700/938] D Loss: 0.6388, G Loss: 0.7836
# Epoch [20/50], Batch [800/938] D Loss: 0.6110, G Loss: 0.9726
# Epoch [20/50], Batch [900/938] D Loss: 0.6059, G Loss: 0.7349
# Epoch [21/50], Batch [100/938] D Loss: 0.6979, G Loss: 0.9082
# Epoch [21/50], Batch [200/938] D Loss: 0.6579, G Loss: 0.8187
# Epoch [21/50], Batch [300/938] D Loss: 0.6072, G Loss: 0.7641
# Epoch [21/50], Batch [400/938] D Loss: 0.6592, G Loss: 0.9540
# Epoch [21/50], Batch [500/938] D Loss: 0.6798, G Loss: 0.9440
# Epoch [21/50], Batch [600/938] D Loss: 0.6802, G Loss: 0.7421
# Epoch [21/50], Batch [700/938] D Loss: 0.6322, G Loss: 0.9355
# Epoch [21/50], Batch [800/938] D Loss: 0.6700, G Loss: 0.8980
# Epoch [21/50], Batch [900/938] D Loss: 0.6135, G Loss: 0.8894
# Epoch [22/50], Batch [100/938] D Loss: 0.6237, G Loss: 0.7901
# Epoch [22/50], Batch [200/938] D Loss: 0.6991, G Loss: 0.9231
# Epoch [22/50], Batch [300/938] D Loss: 0.6573, G Loss: 0.8694
# Epoch [22/50], Batch [400/938] D Loss: 0.6348, G Loss: 0.8234
# Epoch [22/50], Batch [500/938] D Loss: 0.5863, G Loss: 0.8118
# Epoch [22/50], Batch [600/938] D Loss: 0.6503, G Loss: 0.8043
# Epoch [22/50], Batch [700/938] D Loss: 0.6630, G Loss: 0.8589
# Epoch [22/50], Batch [800/938] D Loss: 0.6542, G Loss: 0.9182
# Epoch [22/50], Batch [900/938] D Loss: 0.6082, G Loss: 0.7643
# Epoch [23/50], Batch [100/938] D Loss: 0.6270, G Loss: 0.8985
# Epoch [23/50], Batch [200/938] D Loss: 0.6887, G Loss: 0.8862
# Epoch [23/50], Batch [300/938] D Loss: 0.6876, G Loss: 0.7656
# Epoch [23/50], Batch [400/938] D Loss: 0.6521, G Loss: 0.8304
# Epoch [23/50], Batch [500/938] D Loss: 0.6441, G Loss: 1.0434
# Epoch [23/50], Batch [600/938] D Loss: 0.6292, G Loss: 0.8198
# Epoch [23/50], Batch [700/938] D Loss: 0.6400, G Loss: 0.7249
# Epoch [23/50], Batch [800/938] D Loss: 0.6492, G Loss: 0.7801
# Epoch [23/50], Batch [900/938] D Loss: 0.6840, G Loss: 0.9768
# Epoch [24/50], Batch [100/938] D Loss: 0.6431, G Loss: 0.8272
# Epoch [24/50], Batch [200/938] D Loss: 0.6346, G Loss: 0.8200
# Epoch [24/50], Batch [300/938] D Loss: 0.6403, G Loss: 0.9971
# Epoch [24/50], Batch [400/938] D Loss: 0.6608, G Loss: 0.8001
# Epoch [24/50], Batch [500/938] D Loss: 0.6243, G Loss: 0.8904
# Epoch [24/50], Batch [600/938] D Loss: 0.6508, G Loss: 0.8321
# Epoch [24/50], Batch [700/938] D Loss: 0.7168, G Loss: 1.0066
# Epoch [24/50], Batch [800/938] D Loss: 0.6701, G Loss: 0.9420
# Epoch [24/50], Batch [900/938] D Loss: 0.6514, G Loss: 0.8645
# Epoch [25/50], Batch [100/938] D Loss: 0.6626, G Loss: 0.7472
# Epoch [25/50], Batch [200/938] D Loss: 0.6306, G Loss: 0.8001
# Epoch [25/50], Batch [300/938] D Loss: 0.6817, G Loss: 0.7858
# Epoch [25/50], Batch [400/938] D Loss: 0.6525, G Loss: 0.9216
# Epoch [25/50], Batch [500/938] D Loss: 0.6233, G Loss: 0.7123
# Epoch [25/50], Batch [600/938] D Loss: 0.6638, G Loss: 0.7909
# Epoch [25/50], Batch [700/938] D Loss: 0.6869, G Loss: 0.9021
# Epoch [25/50], Batch [800/938] D Loss: 0.6698, G Loss: 0.9321
# Epoch [25/50], Batch [900/938] D Loss: 0.6846, G Loss: 0.8497
# Epoch [26/50], Batch [100/938] D Loss: 0.6262, G Loss: 0.8055
# Epoch [26/50], Batch [200/938] D Loss: 0.6657, G Loss: 0.7853
# Epoch [26/50], Batch [300/938] D Loss: 0.6838, G Loss: 0.9187
# Epoch [26/50], Batch [400/938] D Loss: 0.6100, G Loss: 0.7715
# Epoch [26/50], Batch [500/938] D Loss: 0.6855, G Loss: 0.8586
# Epoch [26/50], Batch [600/938] D Loss: 0.7172, G Loss: 1.0384
# Epoch [26/50], Batch [700/938] D Loss: 0.6681, G Loss: 0.7417
# Epoch [26/50], Batch [800/938] D Loss: 0.6564, G Loss: 0.7977
# Epoch [26/50], Batch [900/938] D Loss: 0.6712, G Loss: 0.8902
# Epoch [27/50], Batch [100/938] D Loss: 0.7050, G Loss: 0.8981
# Epoch [27/50], Batch [200/938] D Loss: 0.6825, G Loss: 0.7732
# Epoch [27/50], Batch [300/938] D Loss: 0.6606, G Loss: 0.8724
# Epoch [27/50], Batch [400/938] D Loss: 0.7035, G Loss: 0.8352
# Epoch [27/50], Batch [500/938] D Loss: 0.6691, G Loss: 0.7454
# Epoch [27/50], Batch [600/938] D Loss: 0.6820, G Loss: 0.8084
# Epoch [27/50], Batch [700/938] D Loss: 0.6615, G Loss: 0.9035
# Epoch [27/50], Batch [800/938] D Loss: 0.6332, G Loss: 0.9107
# Epoch [27/50], Batch [900/938] D Loss: 0.7158, G Loss: 0.7552
# Epoch [28/50], Batch [100/938] D Loss: 0.6498, G Loss: 0.7401
# Epoch [28/50], Batch [200/938] D Loss: 0.6712, G Loss: 0.8050
# Epoch [28/50], Batch [300/938] D Loss: 0.6898, G Loss: 0.9156
# Epoch [28/50], Batch [400/938] D Loss: 0.6578, G Loss: 0.7723
# Epoch [28/50], Batch [500/938] D Loss: 0.6415, G Loss: 0.8154
# Epoch [28/50], Batch [600/938] D Loss: 0.6462, G Loss: 0.9253
# Epoch [28/50], Batch [700/938] D Loss: 0.6680, G Loss: 0.7480
# Epoch [28/50], Batch [800/938] D Loss: 0.6207, G Loss: 0.8378
# Epoch [28/50], Batch [900/938] D Loss: 0.6483, G Loss: 0.7605
# Epoch [29/50], Batch [100/938] D Loss: 0.6258, G Loss: 0.7807
# Epoch [29/50], Batch [200/938] D Loss: 0.6343, G Loss: 0.7965
# Epoch [29/50], Batch [300/938] D Loss: 0.6342, G Loss: 0.7870
# Epoch [29/50], Batch [400/938] D Loss: 0.6443, G Loss: 0.7964
# Epoch [29/50], Batch [500/938] D Loss: 0.6684, G Loss: 0.8812
# Epoch [29/50], Batch [600/938] D Loss: 0.6604, G Loss: 0.8082
# Epoch [29/50], Batch [700/938] D Loss: 0.6346, G Loss: 0.9089
# Epoch [29/50], Batch [800/938] D Loss: 0.6578, G Loss: 0.7679
# Epoch [29/50], Batch [900/938] D Loss: 0.6356, G Loss: 0.8116
# Epoch [30/50], Batch [100/938] D Loss: 0.6160, G Loss: 0.8285
# Epoch [30/50], Batch [200/938] D Loss: 0.6922, G Loss: 0.8969
# Epoch [30/50], Batch [300/938] D Loss: 0.6408, G Loss: 0.7612
# Epoch [30/50], Batch [400/938] D Loss: 0.6808, G Loss: 0.7380
# Epoch [30/50], Batch [500/938] D Loss: 0.6479, G Loss: 0.8397
# Epoch [30/50], Batch [600/938] D Loss: 0.6200, G Loss: 0.8098
# Epoch [30/50], Batch [700/938] D Loss: 0.6586, G Loss: 0.8953
# Epoch [30/50], Batch [800/938] D Loss: 0.6445, G Loss: 0.8706
# Epoch [30/50], Batch [900/938] D Loss: 0.6486, G Loss: 0.8474
# Epoch [31/50], Batch [100/938] D Loss: 0.6784, G Loss: 0.8830
# Epoch [31/50], Batch [200/938] D Loss: 0.6531, G Loss: 0.8296
# Epoch [31/50], Batch [300/938] D Loss: 0.6389, G Loss: 0.8282
# Epoch [31/50], Batch [400/938] D Loss: 0.6870, G Loss: 0.7741
# Epoch [31/50], Batch [500/938] D Loss: 0.6753, G Loss: 0.7322
# Epoch [31/50], Batch [600/938] D Loss: 0.6423, G Loss: 0.8638
# Epoch [31/50], Batch [700/938] D Loss: 0.6326, G Loss: 0.7885
# Epoch [31/50], Batch [800/938] D Loss: 0.6456, G Loss: 0.7878
# Epoch [31/50], Batch [900/938] D Loss: 0.6768, G Loss: 0.8502
# Epoch [32/50], Batch [100/938] D Loss: 0.6840, G Loss: 1.0287
# Epoch [32/50], Batch [200/938] D Loss: 0.6890, G Loss: 0.8101
# Epoch [32/50], Batch [300/938] D Loss: 0.6806, G Loss: 0.9375
# Epoch [32/50], Batch [400/938] D Loss: 0.6826, G Loss: 0.7773
# Epoch [32/50], Batch [500/938] D Loss: 0.6588, G Loss: 0.8406
# Epoch [32/50], Batch [600/938] D Loss: 0.7136, G Loss: 0.8119
# Epoch [32/50], Batch [700/938] D Loss: 0.6989, G Loss: 0.8001
# Epoch [32/50], Batch [800/938] D Loss: 0.6464, G Loss: 0.7659
# Epoch [32/50], Batch [900/938] D Loss: 0.6252, G Loss: 0.8013
# Epoch [33/50], Batch [100/938] D Loss: 0.7068, G Loss: 0.8028
# Epoch [33/50], Batch [200/938] D Loss: 0.6402, G Loss: 0.8796
# Epoch [33/50], Batch [300/938] D Loss: 0.6179, G Loss: 0.8153
# Epoch [33/50], Batch [400/938] D Loss: 0.6162, G Loss: 0.6971
# Epoch [33/50], Batch [500/938] D Loss: 0.6421, G Loss: 0.8665
# Epoch [33/50], Batch [600/938] D Loss: 0.6435, G Loss: 0.8756
# Epoch [33/50], Batch [700/938] D Loss: 0.6313, G Loss: 0.7630
# Epoch [33/50], Batch [800/938] D Loss: 0.6922, G Loss: 0.7939
# Epoch [33/50], Batch [900/938] D Loss: 0.6437, G Loss: 0.7859
# Epoch [34/50], Batch [100/938] D Loss: 0.6815, G Loss: 0.8180
# Epoch [34/50], Batch [200/938] D Loss: 0.6141, G Loss: 0.8141
# Epoch [34/50], Batch [300/938] D Loss: 0.6419, G Loss: 0.8658
# Epoch [34/50], Batch [400/938] D Loss: 0.6565, G Loss: 0.8680
# Epoch [34/50], Batch [500/938] D Loss: 0.6789, G Loss: 0.8124
# Epoch [34/50], Batch [600/938] D Loss: 0.6988, G Loss: 0.7586
# Epoch [34/50], Batch [700/938] D Loss: 0.6805, G Loss: 0.8962
# Epoch [34/50], Batch [800/938] D Loss: 0.6808, G Loss: 0.8094
# Epoch [34/50], Batch [900/938] D Loss: 0.6778, G Loss: 0.7618
# Epoch [35/50], Batch [100/938] D Loss: 0.6085, G Loss: 0.8436
# Epoch [35/50], Batch [200/938] D Loss: 0.6633, G Loss: 0.9210
# Epoch [35/50], Batch [300/938] D Loss: 0.6771, G Loss: 0.8662
# Epoch [35/50], Batch [400/938] D Loss: 0.6743, G Loss: 0.9921
# Epoch [35/50], Batch [500/938] D Loss: 0.6579, G Loss: 0.6786
# Epoch [35/50], Batch [600/938] D Loss: 0.6485, G Loss: 0.7209
# Epoch [35/50], Batch [700/938] D Loss: 0.6739, G Loss: 0.8300
# Epoch [35/50], Batch [800/938] D Loss: 0.6499, G Loss: 0.8915
# Epoch [35/50], Batch [900/938] D Loss: 0.6842, G Loss: 0.9310
# Epoch [36/50], Batch [100/938] D Loss: 0.6543, G Loss: 0.7456
# Epoch [36/50], Batch [200/938] D Loss: 0.7034, G Loss: 0.8767
# Epoch [36/50], Batch [300/938] D Loss: 0.6536, G Loss: 0.7802
# Epoch [36/50], Batch [400/938] D Loss: 0.6601, G Loss: 0.7388
# Epoch [36/50], Batch [500/938] D Loss: 0.6724, G Loss: 0.6664
# Epoch [36/50], Batch [600/938] D Loss: 0.6369, G Loss: 0.7960
# Epoch [36/50], Batch [700/938] D Loss: 0.6861, G Loss: 0.8144
# Epoch [36/50], Batch [800/938] D Loss: 0.7019, G Loss: 0.8796
# Epoch [36/50], Batch [900/938] D Loss: 0.7109, G Loss: 0.7794
# Epoch [37/50], Batch [100/938] D Loss: 0.6422, G Loss: 0.9065
# Epoch [37/50], Batch [200/938] D Loss: 0.6410, G Loss: 0.9421
# Epoch [37/50], Batch [300/938] D Loss: 0.6515, G Loss: 0.8035
# Epoch [37/50], Batch [400/938] D Loss: 0.6538, G Loss: 0.8629
# Epoch [37/50], Batch [500/938] D Loss: 0.6583, G Loss: 0.8402
# Epoch [37/50], Batch [600/938] D Loss: 0.6931, G Loss: 0.8708
# Epoch [37/50], Batch [700/938] D Loss: 0.6561, G Loss: 0.8190
# Epoch [37/50], Batch [800/938] D Loss: 0.6452, G Loss: 0.7364
# Epoch [37/50], Batch [900/938] D Loss: 0.6502, G Loss: 0.9116
# Epoch [38/50], Batch [100/938] D Loss: 0.6476, G Loss: 0.8102
# Epoch [38/50], Batch [200/938] D Loss: 0.6619, G Loss: 0.7427
# Epoch [38/50], Batch [300/938] D Loss: 0.6451, G Loss: 0.8836
# Epoch [38/50], Batch [400/938] D Loss: 0.6352, G Loss: 0.8564
# Epoch [38/50], Batch [500/938] D Loss: 0.6602, G Loss: 0.7944
# Epoch [38/50], Batch [600/938] D Loss: 0.6454, G Loss: 0.6892
# Epoch [38/50], Batch [700/938] D Loss: 0.6967, G Loss: 0.7495
# Epoch [38/50], Batch [800/938] D Loss: 0.6806, G Loss: 0.7504
# Epoch [38/50], Batch [900/938] D Loss: 0.6683, G Loss: 0.8035
# Epoch [39/50], Batch [100/938] D Loss: 0.6562, G Loss: 0.8371
# Epoch [39/50], Batch [200/938] D Loss: 0.6602, G Loss: 0.8118
# Epoch [39/50], Batch [300/938] D Loss: 0.6558, G Loss: 0.7981
# Epoch [39/50], Batch [400/938] D Loss: 0.6689, G Loss: 0.8018
# Epoch [39/50], Batch [500/938] D Loss: 0.6236, G Loss: 0.7693
# Epoch [39/50], Batch [600/938] D Loss: 0.6828, G Loss: 0.7556
# Epoch [39/50], Batch [700/938] D Loss: 0.6347, G Loss: 0.8410
# Epoch [39/50], Batch [800/938] D Loss: 0.6936, G Loss: 0.9017
# Epoch [39/50], Batch [900/938] D Loss: 0.6328, G Loss: 0.8653
# Epoch [40/50], Batch [100/938] D Loss: 0.7019, G Loss: 0.9190
# Epoch [40/50], Batch [200/938] D Loss: 0.6709, G Loss: 0.7773
# Epoch [40/50], Batch [300/938] D Loss: 0.6820, G Loss: 0.8497
# Epoch [40/50], Batch [400/938] D Loss: 0.6441, G Loss: 0.7265
# Epoch [40/50], Batch [500/938] D Loss: 0.6298, G Loss: 0.9011
# Epoch [40/50], Batch [600/938] D Loss: 0.6486, G Loss: 0.7634
# Epoch [40/50], Batch [700/938] D Loss: 0.6602, G Loss: 0.9487
# Epoch [40/50], Batch [800/938] D Loss: 0.6405, G Loss: 0.8300
# Epoch [40/50], Batch [900/938] D Loss: 0.6538, G Loss: 0.9216
# Epoch [41/50], Batch [100/938] D Loss: 0.6907, G Loss: 0.7366
# Epoch [41/50], Batch [200/938] D Loss: 0.6828, G Loss: 0.7359
# Epoch [41/50], Batch [300/938] D Loss: 0.6821, G Loss: 0.7008
# Epoch [41/50], Batch [400/938] D Loss: 0.6761, G Loss: 0.7836
# Epoch [41/50], Batch [500/938] D Loss: 0.6788, G Loss: 0.8030
# Epoch [41/50], Batch [600/938] D Loss: 0.6641, G Loss: 0.7770
# Epoch [41/50], Batch [700/938] D Loss: 0.6878, G Loss: 0.7662
# Epoch [41/50], Batch [800/938] D Loss: 0.6501, G Loss: 0.8063
# Epoch [41/50], Batch [900/938] D Loss: 0.7133, G Loss: 0.8359
# Epoch [42/50], Batch [100/938] D Loss: 0.6678, G Loss: 0.8142
# Epoch [42/50], Batch [200/938] D Loss: 0.6741, G Loss: 0.7437
# Epoch [42/50], Batch [300/938] D Loss: 0.6401, G Loss: 0.7494
# Epoch [42/50], Batch [400/938] D Loss: 0.6840, G Loss: 0.7670
# Epoch [42/50], Batch [500/938] D Loss: 0.6441, G Loss: 0.8669
# Epoch [42/50], Batch [600/938] D Loss: 0.6715, G Loss: 0.9222
# Epoch [42/50], Batch [700/938] D Loss: 0.6802, G Loss: 0.7869
# Epoch [42/50], Batch [800/938] D Loss: 0.7352, G Loss: 0.8538
# Epoch [42/50], Batch [900/938] D Loss: 0.6658, G Loss: 0.7722
# Epoch [43/50], Batch [100/938] D Loss: 0.6373, G Loss: 0.8640
# Epoch [43/50], Batch [200/938] D Loss: 0.6737, G Loss: 0.8680
# Epoch [43/50], Batch [300/938] D Loss: 0.6610, G Loss: 0.7237
# Epoch [43/50], Batch [400/938] D Loss: 0.6569, G Loss: 0.8239
# Epoch [43/50], Batch [500/938] D Loss: 0.6456, G Loss: 0.8655
# Epoch [43/50], Batch [600/938] D Loss: 0.6709, G Loss: 0.7226
# Epoch [43/50], Batch [700/938] D Loss: 0.6981, G Loss: 0.7878
# Epoch [43/50], Batch [800/938] D Loss: 0.7175, G Loss: 0.7782
# Epoch [43/50], Batch [900/938] D Loss: 0.6428, G Loss: 0.8089
# Epoch [44/50], Batch [100/938] D Loss: 0.6554, G Loss: 0.8574
# Epoch [44/50], Batch [200/938] D Loss: 0.6748, G Loss: 0.8757
# Epoch [44/50], Batch [300/938] D Loss: 0.6638, G Loss: 0.8698
# Epoch [44/50], Batch [400/938] D Loss: 0.6552, G Loss: 0.7238
# Epoch [44/50], Batch [500/938] D Loss: 0.6569, G Loss: 0.9066
# Epoch [44/50], Batch [600/938] D Loss: 0.6480, G Loss: 0.8651
# Epoch [44/50], Batch [700/938] D Loss: 0.6691, G Loss: 0.8160
# Epoch [44/50], Batch [800/938] D Loss: 0.6483, G Loss: 0.9382
# Epoch [44/50], Batch [900/938] D Loss: 0.6732, G Loss: 0.8452
# Epoch [45/50], Batch [100/938] D Loss: 0.6456, G Loss: 0.7818
# Epoch [45/50], Batch [200/938] D Loss: 0.6818, G Loss: 0.9275
# Epoch [45/50], Batch [300/938] D Loss: 0.6848, G Loss: 0.7271
# Epoch [45/50], Batch [400/938] D Loss: 0.6295, G Loss: 0.8287
# Epoch [45/50], Batch [500/938] D Loss: 0.6590, G Loss: 0.7867
# Epoch [45/50], Batch [600/938] D Loss: 0.6470, G Loss: 0.8560
# Epoch [45/50], Batch [700/938] D Loss: 0.6599, G Loss: 0.8431
# Epoch [45/50], Batch [800/938] D Loss: 0.6268, G Loss: 0.7684
# Epoch [45/50], Batch [900/938] D Loss: 0.6537, G Loss: 0.6938
# Epoch [46/50], Batch [100/938] D Loss: 0.6665, G Loss: 0.8036
# Epoch [46/50], Batch [200/938] D Loss: 0.6255, G Loss: 0.8540
# Epoch [46/50], Batch [300/938] D Loss: 0.6612, G Loss: 0.9160
# Epoch [46/50], Batch [400/938] D Loss: 0.6328, G Loss: 0.8900
# Epoch [46/50], Batch [500/938] D Loss: 0.6589, G Loss: 0.7437
# Epoch [46/50], Batch [600/938] D Loss: 0.6342, G Loss: 0.7288
# Epoch [46/50], Batch [700/938] D Loss: 0.6658, G Loss: 0.8423
# Epoch [46/50], Batch [800/938] D Loss: 0.6446, G Loss: 0.8255
# Epoch [46/50], Batch [900/938] D Loss: 0.6884, G Loss: 0.8415
# Epoch [47/50], Batch [100/938] D Loss: 0.6196, G Loss: 0.7915
# Epoch [47/50], Batch [200/938] D Loss: 0.6558, G Loss: 0.7780
# Epoch [47/50], Batch [300/938] D Loss: 0.6490, G Loss: 0.8186
# Epoch [47/50], Batch [400/938] D Loss: 0.6577, G Loss: 0.7663
# Epoch [47/50], Batch [500/938] D Loss: 0.6579, G Loss: 0.7723
# Epoch [47/50], Batch [600/938] D Loss: 0.6632, G Loss: 0.8032
# Epoch [47/50], Batch [700/938] D Loss: 0.6828, G Loss: 0.7257
# Epoch [47/50], Batch [800/938] D Loss: 0.6584, G Loss: 0.8012
# Epoch [47/50], Batch [900/938] D Loss: 0.6105, G Loss: 0.7912
# Epoch [48/50], Batch [100/938] D Loss: 0.6722, G Loss: 0.8659
# Epoch [48/50], Batch [200/938] D Loss: 0.6420, G Loss: 0.7595
# Epoch [48/50], Batch [300/938] D Loss: 0.6123, G Loss: 0.7762
# Epoch [48/50], Batch [400/938] D Loss: 0.6175, G Loss: 0.8015
# Epoch [48/50], Batch [500/938] D Loss: 0.6479, G Loss: 0.8206
# Epoch [48/50], Batch [600/938] D Loss: 0.6545, G Loss: 0.7826
# Epoch [48/50], Batch [700/938] D Loss: 0.6661, G Loss: 0.8393
# Epoch [48/50], Batch [800/938] D Loss: 0.6817, G Loss: 0.8202
# Epoch [48/50], Batch [900/938] D Loss: 0.6459, G Loss: 0.7100
# Epoch [49/50], Batch [100/938] D Loss: 0.6452, G Loss: 0.8283
# Epoch [49/50], Batch [200/938] D Loss: 0.6280, G Loss: 0.7416
# Epoch [49/50], Batch [300/938] D Loss: 0.6521, G Loss: 0.8708
# Epoch [49/50], Batch [400/938] D Loss: 0.6821, G Loss: 0.7662
# Epoch [49/50], Batch [500/938] D Loss: 0.6858, G Loss: 0.8135
# Epoch [49/50], Batch [600/938] D Loss: 0.6778, G Loss: 0.7266
# Epoch [49/50], Batch [700/938] D Loss: 0.6559, G Loss: 0.7882
# Epoch [49/50], Batch [800/938] D Loss: 0.7298, G Loss: 0.7561
# Epoch [49/50], Batch [900/938] D Loss: 0.6220, G Loss: 0.7922
# Epoch [50/50], Batch [100/938] D Loss: 0.6702, G Loss: 0.7866
# Epoch [50/50], Batch [200/938] D Loss: 0.6562, G Loss: 0.7694
# Epoch [50/50], Batch [300/938] D Loss: 0.6727, G Loss: 0.7762
# Epoch [50/50], Batch [400/938] D Loss: 0.6606, G Loss: 0.7410
# Epoch [50/50], Batch [500/938] D Loss: 0.6546, G Loss: 0.8687
# Epoch [50/50], Batch [600/938] D Loss: 0.6496, G Loss: 0.7749
# Epoch [50/50], Batch [700/938] D Loss: 0.6431, G Loss: 0.9442
# Epoch [50/50], Batch [800/938] D Loss: 0.6729, G Loss: 0.8668
# Epoch [50/50], Batch [900/938] D Loss: 0.6296, G Loss: 0.8128
# Training complete. Conditional Generator model saved as conditional_generator_mnist.pth
